# %%
# Here we import everything we need for the project

# %matplotlib inline
#from google.colab import files
import os

# TensorFlow and tf.keras
#import tensorflow as tf
#from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import cv2
import pandas as pd
import torchvision

# Sklearn
#from sklearn.model_selection import train_test_split # Helps with organizing data for training
#from sklearn.metrics import confusion_matrix # Helps present results as a confusion-matrix

#print(tf.__version__)

# %%
imagepaths = []

# Go through all the files and subdirectories inside a folder and save path to images inside list
for root, dirs, files in os.walk(".", topdown=False): 
  for name in files:
    path = os.path.join(root, name)
    if path.endswith("csv"): # We want only the images
      imagepaths.append(path)

print(len(imagepaths)) # If > 0, then a PNG image was loaded
# Out:
# 1253

# %%
def plot_image(path):
    data = pd.read_csv(path,header=None)
    ii = data.iloc[:,:138]
    qq = data.iloc[:,138:]
    complexqq = qq*1j
    iq = ii.add(complexqq, fill_value=0)
    plt.figure(figsize = (100,50))
    plt.imshow(abs(iq))
    plt.xlabel("Fast time")
    plt.ylabel("Slow time")
    plt.title("Image " + path)

# %%
plot_image(imagepaths[1000])

# %%
import torch
import glob
from torch.utils.data import Dataset
class FeatureDataset(Dataset):
    
    def __init__(self, x_path):
        
        x_filenames = glob.glob(x_path + '*.csv')
        for filename in x_filenames:
            data = pd.read_csv(filename)
            ii = data.iloc[:,:138]
            qq = data.iloc[:,138:]
            complexqq = qq*1j
            iq = ii.add(complexqq, fill_value=0)
            self.X_train = torch.tensor(iq.values, dtype=torch.float32)
            
            self.len = len(self.X_train) # Size of data
    
    def __len__(self):
        return len(self.X_train)

    def __getitem__(self, idx):
        return self.X_train[idx]

# %%
data = FeatureDataset('./Dataset/GestureA/0 degree/')
len(data)
# Out:
# 640
